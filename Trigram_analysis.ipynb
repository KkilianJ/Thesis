# %% [markdown]
# <a href="https://colab.research.google.com/github/KkilianJ/Thesis/blob/main/Trigram_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
long_text = '/content/drive/MyDrive/Thesis/long_text_with_pos_text.csv'
short_text = '/content/drive/MyDrive/Thesis/short_text_with_pos_text.csv'
df_long = pd.read_csv(long_text, low_memory=False)
df_short = pd.read_csv(short_text, low_memory = False)
# Out:
#                                                  text  viewCount  likeCount  \
# 0   @CynCity1243 @MikeRoy_Cit12 @GastricpH Likewis...       49.0        0.0
# 1   @Megatron_ron France should take in Lebanese r...       84.0        1.0
# 2   @TiltingNBA @majornija @nicole_naiya Heard thi...        4.0        0.0
# 3   Guys.\n\nDonald Trump is quite literally the l...      159.0        6.0
# 4   @realDonaldTrump The American people have endu...     2274.0       74.0
# 5   @legitbrittFLA @TrumpDailyPosts Yes, the USA a...       19.0        1.0
# 6   @2Strong2Silence Angry Staffer said the other ...       33.0        2.0
# 7   Biden's Numbers: April 2024 Update, the S&amp;...      152.0        0.0
# 8   @elonmusk MN Governor Tim Walz News...\n\nAs D...        3.0        0.0
# 9   @RealChadEros @brianlilley @joe_warmington @Ju...       19.0        0.0
# 10  @GenFlynn @patriottvnet @FlynnMovie @boonecutl...        5.0        0.0
# 11  From MJTruth…\n\n• The newest hoax against Tru...        5.0        0.0
# 12  #RightBias\nCriminal indicted on murder charge...       22.0        0.0
# 13  @kaitlancollins Excellent! Praise God from who...       11.0        0.0
# 14  @CollinRugg @JakeSherman @JMRaasch Both sad &a...        8.0        0.0
# 15  @DougTenNapel I agree. Yet with Trumps constan...       27.0        1.0
# 16  @Mushrumination @debdeb23 @david_lonsinger @vv...       19.0        0.0
# 17  @kremsnite @AlPutino @elonmusk @Tesla @teslaen...       35.0        0.0
# 18  @Tayloh25 @Tamzilla_52 @marybeth5025 Looks mor...       42.0        0.0
# 19  @Alexmipego 1) This is politics, not the justi...     3268.0       91.0
# 20  @RNCResearch Doctors lawyers scientists engine...        7.0        0.0
# 21  @ronrak @NEWSMAX Speech review\nm9 Brdr crossi...        9.0        0.0
# 22  @CSL_Invest What Mulroney did was make the Can...      155.0        2.0
# 23  @kcmsinned @acnewsitics The difference between...       13.0        2.0
# 24  @GenMhayden Oh please. The Shame should be urs...        5.0        0.0
# 25  Pravda Minneapolis received the DNC memo for t...       70.0        0.0
# 26  @LaurenBaratzL It's the story. Let's have a be...       10.0        0.0
# 27  🌟 The Gila River Indian Community in AZ is get...       11.0        1.0
# 28  It’s nice to see Miami (D)s &amp; (R)s enjoyin...    16951.0       14.0
# 29  @JJon1983 @Logically_JC "Recent data shows the...       10.0        0.0
#
#     quoteCount  replyCount  retweetCount  char_count  \
# 0          0.0         1.0           0.0         320
# 1          0.0         0.0           0.0         283
# 2          0.0         0.0           0.0         338
# 3          0.0         0.0           3.0         303
# 4          3.0         3.0          24.0         318
# 5          0.0         0.0           0.0         311
# 6          0.0         0.0           0.0         287
# 7          0.0         0.0           0.0         284
# 8          0.0         0.0           0.0         289
# 9          0.0         1.0           0.0         327
# 10         0.0         0.0           0.0         299
# 11         0.0         0.0           0.0         291
# 12         0.0         0.0           0.0         299
# 13         0.0         0.0           0.0         312
# 14         0.0         0.0           0.0         329
# 15         0.0         0.0           0.0         294
# 16         0.0         1.0           0.0         328
# 17         0.0         0.0           0.0         328
# 18         0.0         1.0           0.0         313
# 19         0.0         2.0          11.0         289
# 20         0.0         0.0           0.0         293
# 21         0.0         0.0           0.0         288
# 22         0.0         1.0           3.0         290
# 23         0.0         0.0           0.0         303
# 24         0.0         0.0           0.0         296
# 25         0.0         0.0           0.0         296
# 26         0.0         0.0           0.0         294
# 27         0.0         0.0           1.0         304
# 28         2.0         3.0           3.0         308
# 29         0.0         1.0           0.0         304
#
#                                           bigram_text
# 0   likewise kennedy is famously a democrat i was ...
# 1   france should take in lebanese refugees as wel...
# 2   heard this before and the numbers just get wor...
# 3   guys donald trump is quite literally the law h...
# 4   the american people have endured so much at th...
# 5   yes the usa affects the world economy however ...
# 6   angry staffer said the other day in response t...
# 7   bidens numbers april 2024 update the sampp 500...
# 8   mn governor tim walz news as democrats scrambl...
# 9   the cpc is up by four touchdowns in the 4th qu...
# 10  trump could beat the sly dems at their own gam...
# 11  from mjtruth the newest hoax against trump i n...
# 12  criminal indicted on murder charge freed witho...
# 13  excellent praise god from whom all blessing fl...
# 14  both sad amp funny at the same time to see the...
# 15  i agree yet with trumps constant shift left by...
# 16  if nothing else please take away from this con...
# 17  clean air clean water and the environment trum...
# 18  looks more like a biden catholic by the minute...
# 19  1 this is politics not the justice system bide...
# 20  doctors lawyers scientists engineers plumbers ...
# 21  speech review m9 brdr crossings lower today th...
# 22  what mulroney did was make the canadian dollar...
# 23  the difference between these two is donald tru...
# 24  oh please the shame should be urs amp anyone e...
# 25  pravda minneapolis received the dnc memo for t...
# 26  its the story lets have a better candidate in ...
# 27  the gila river indian community in az is getti...
# 28  its nice to see miami ds amp rs enjoying genia...
# 29  recent data shows the trend is likely baked in...

# %%
import re
from collections import Counter
from multiprocessing import Pool
from math import sqrt
from tqdm import tqdm

long_tweets = df_long['bigram_text'].tolist()
short_tweets = df_short['bigram_text'].tolist()

name_tokens = {"donald","trump","joe","biden","kamala","harris","j.d.","vance","tim","walz","robert","kennedy"}

def extract_trigrams(texts):
    counts = Counter()
    for text in texts:
        words = text.split()
        for i in range(len(words) - 2):
            tri = (words[i], words[i+1], words[i+2])
            if "amp" in tri or any(token in name_tokens for token in tri):
                continue
            counts[" ".join(tri)] += 1
    return counts

def count_trigrams(texts, processes=44, chunk_size=100_000):
    chunks = [texts[i:i+chunk_size] for i in range(0, len(texts), chunk_size)]
    summary = Counter()
    with Pool(processes) as pool:
        for part in tqdm(pool.imap(extract_trigrams, chunks), total=len(chunks), desc="Counting trigrams"):
            summary.update(part)
    return summary

def compute_t_scores(short_counts, long_counts, min_freq=50):
    Ns = sum(short_counts.values())
    Nl = sum(long_counts.values())
    records = []
    all_tris = set(short_counts) | set(long_counts)
    for tri in tqdm(all_tris, desc="Scoring trigrams"):
        fs = short_counts.get(tri, 0)
        fl = long_counts.get(tri, 0)
        if fs + fl < min_freq:
            continue
        ps, pl = fs / Ns, fl / Nl
        var = ps / Ns + pl / Nl
        if var <= 0:
            continue
        t = (pl - ps) / sqrt(var)
        if t >= 2:
            cat = "increase"
        elif t <= -2:
            cat = "decrease"
        else:
            cat = "neutral"
        records.append((tri, t, fs, fl, cat))
    return pd.DataFrame(records, columns=['trigram','t_score','freq_short','freq_long','category'])

short_counts = count_trigrams(short_tweets)
long_counts = count_trigrams(long_tweets)
df_results = compute_t_scores(short_counts, long_counts)

df_increase = df_results[df_results.category == 'increase']
df_decrease = df_results[df_results.category == 'decrease']
df_neutral  = df_results[df_results.category == 'neutral']
# Out:
# Counting trigrams: 100%|██████████| 30/30 [00:30<00:00,  1.03s/it]
# Counting trigrams: 100%|██████████| 30/30 [01:23<00:00,  2.79s/it]
# Scoring trigrams: 100%|██████████| 57131841/57131841 [00:59<00:00, 963200.00it/s]
#                     trigram    t_score  freq_short  freq_long  category
# 2            started no new   3.327142          16         84  increase
# 5            people who put   2.138410          40        140  increase
# 8            no interest in   2.752489         305        893  increase
# 15               i use that   4.335906          10         75  increase
# 34            opened up the   3.058376          80        281  increase
# 35             have to like   2.311672         141        429  increase
# 59              and plot to  11.895855           1        152  increase
# 74         us citizens have   5.465583          21        141  increase
# 87              in a recent   3.859284         168        566  increase
# 97            isnt just the   3.615472          41        175  increase
# 108            but when you   4.293915         196        666  increase
# 113      most successful in   2.252051          10         48  increase
# 114        in politics they   2.421957          10         50  increase
# 119           of voters who   2.253814         129        394  increase
# 121   passed legislation to   3.544678           9         60  increase
# 133    the bidenharris 2024   2.625148           8         45  increase
# 136        are correct that   3.560806          25        120  increase
# 143               at all or   2.516185          65        222  increase
# 145            border to be   6.363357          27        185  increase
# 148             his kids in   2.048931          20         78  increase
# 155     and other political   2.252051          10         48  increase
# 161    officers in congress   7.251251           2         71  increase
# 165            the worst it   2.341116          12         56  increase
# 166       voting for people   2.077632          27        100  increase
# 170      russia and ukraine   2.470621         214        634  increase
# 187            mean old man   6.133028          11        108  increase
# 193           where she was   2.097919          77        245  increase
# 205         be motivated to   2.459549          11         54  increase
# 208     change the election   2.092559          23         88  increase
# 218                i see as   3.157846          17         85  increase
# 219             we urge you   4.494998           4         48  increase
# 221          over 2 million   3.592334          36        158  increase
# 222             right up to   4.197128          63        261  increase
# 247      allow control over  10.295630           0        106  increase
# 248              part of it   2.514527         479       1340  increase
# 249              her no one   2.309598          20         82  increase
# 251               i ask how   2.505832          10         51  increase
# 257      that regardless of   3.245340          20         97  increase
# 259             who have to   2.236428          70        229  increase
# 261           from them and   2.610475          55        195  increase
# 265        his followers to   3.364514          83        299  increase
# 272           is failing to   3.759666          19        102  increase
# 282           ive seen many   2.098663          22         85  increase
# 290         that dont agree   3.049360          23        104  increase
# 291  in conservative states   2.129056          30        110  increase
# 295         and forced them   2.535226           8         44  increase
# 311           gave the rich   2.589008          10         52  increase
# 314         of education in   2.761456          13         65  increase
# 315            the next gen   2.261687          12         55  increase
# 324            i do however   2.952963          25        109  increase
#                              trigram    t_score  freq_short  freq_long  \
# 3                   watching all the  -2.081960          49         80
# 4                 the working people  -2.228541          91        164
# 11                are fucking stupid  -3.931474          34         24
# 17                    why arent more  -2.440977          28         34
# 20                      will stop at  -2.635001         259        516
# 22                  gop candidate is  -3.022504          86        134
# 30              republicans ahead of  -5.643949          45         15
# 38                 do anything right  -5.496583          79         66
# 46   democratic presidential nominee  -4.071146         255        445
# 49                    around the dnc  -2.276979          29         38
# 50                       so much hes  -2.528750          38         51
# 52                      this wont be  -2.555202          56         85
# 53                      this this is  -7.389630         473        720
# 54                 really really bad  -2.955077          59         83
# 69                      he said this  -2.362291         145        276
# 70                      how much did -11.598715         489        518
# 76                       im on board  -3.057161          31         31
# 77               you fucking kidding  -3.914622          85        111
# 82                  is clearly unfit  -2.709599          34         41
# 95                quite possibly the  -2.640495          34         42
# 100                     and be quiet  -2.710972          39         50
# 103                     to lead this  -2.958621         158        284
# 110                  youre a traitor  -2.515052         106        188
# 118                thing for america  -2.655770          57         85
# 124                   fact check via  -7.619817          60          2
# 127                      an easy win  -3.180815         115        188
# 129                    are not going  -6.202702        1104       2130
# 139                   right vote for  -2.206318          23         28
# 140                    why havent we  -2.825280          54         76
# 147                  message for the  -4.955211          72         66
# 164          president bidens debate  -2.528750          38         51
# 168                  thats not going  -2.492799         153        289
# 169                      what a jerk  -4.294818          36         22
# 172                    are voted out  -2.039242          23         30
# 173                  even stay awake  -2.327108          31         41
# 178                 for running mate  -3.507796          29         22
# 186                       dei is the  -3.010009          33         35
# 191                was just thinking  -5.239720          88         86
# 195                   joke just like  -3.711880          41         38
# 197                democrats this is  -2.694320         105        181
# 212                        so we all  -3.427688          90        132
# 216               stop this insanity  -2.404902          52         80
# 229                        to pull a  -3.237877         150        258
# 230                     stage at the  -8.690847         309        350
# 237                      him as well  -2.812632         122        213
# 258                      crook and a  -4.667487          54         43
# 260                   anyone tell me  -2.810485          57         82
# 262              do maga republicans  -3.669509          33         26
# 263                      want to die  -2.942267          81        126
# 264                    a pretty good  -4.901282         258        416
#
#      category
# 3    decrease
# 4    decrease
# 11   decrease
# 17   decrease
# 20   decrease
# 22   decrease
# 30   decrease
# 38   decrease
# 46   decrease
# 49   decrease
# 50   decrease
# 52   decrease
# 53   decrease
# 54   decrease
# 69   decrease
# 70   decrease
# 76   decrease
# 77   decrease
# 82   decrease
# 95   decrease
# 100  decrease
# 103  decrease
# 110  decrease
# 118  decrease
# 124  decrease
# 127  decrease
# 129  decrease
# 139  decrease
# 140  decrease
# 147  decrease
# 164  decrease
# 168  decrease
# 169  decrease
# 172  decrease
# 173  decrease
# 178  decrease
# 186  decrease
# 191  decrease
# 195  decrease
# 197  decrease
# 212  decrease
# 216  decrease
# 229  decrease
# 230  decrease
# 237  decrease
# 258  decrease
# 260  decrease
# 262  decrease
# 263  decrease
# 264  decrease
#                   trigram   t_score  freq_short  freq_long category
# 0     doing their bidding  0.219044          20         52  neutral
# 1         course you have  0.056602          33         82  neutral
# 6          years you were  1.110181          15         50  neutral
# 7             women it is  1.594627          13         50  neutral
# 9             oh and lets  0.425885          29         78  neutral
# 10             had it all -0.725340          36         76  neutral
# 12          fucked up and -0.234549          50        118  neutral
# 13           can still be -1.653141         147        304  neutral
# 14         has a positive -0.801085          20         39  neutral
# 16             vivek is a  1.034406          29         88  neutral
# 18        the press corps -0.765060          42         89  neutral
# 19        im grateful for -0.436946          53        121  neutral
# 21       stopping the war -0.538649          26         56  neutral
# 23  are american citizens -1.906253          44         73  neutral
# 24            by a couple -0.566210          37         81  neutral
# 25             sent a mob  0.993971          18         57  neutral
# 26          them over the  1.395767          63        188  neutral
# 27            dead at the -0.754818          22         44  neutral
# 28         so great about  0.902673          12         39  neutral
# 29          not a typical -0.784990          19         37  neutral
# 31          system in the  1.276512          60        177  neutral
# 32         fox news would -1.155385          23         41  neutral
# 33          the same dumb  0.396702          16         44  neutral
# 36             outed as a -1.246814          25         44  neutral
# 37             it why did  1.501732          35        113  neutral
# 39       to help families  1.131415          17         56  neutral
# 40           on stage for -0.810955          45         95  neutral
# 41        the polls which  1.729198          16         61  neutral
# 42          person i have  1.620575          29         98  neutral
# 43        best to destroy -0.014455          29         71  neutral
# 44        america we know  0.815666          27         79  neutral
# 45      democracy at work -0.488803          17         36  neutral
# 47            to have all  1.267394          78        225  neutral
# 48        he will release -1.077803          23         42  neutral
# 51           that 4 years -1.894084          56         98  neutral
# 55          and the mayor  0.143997          18         46  neutral
# 56      voting jill stein  0.462693          42        112  neutral
# 57       falling into the  1.639865          32        107  neutral
# 58           25 years ago -0.319060          67        157  neutral
# 60        thats not right  0.253883          21         55  neutral
# 61          times as many  0.320294          34         89  neutral
# 62         he didnt break  0.992976          12         40  neutral
# 63          to america on -0.373443          22         49  neutral
# 64          point you can  0.723908          16         48  neutral
# 65           the issue he  1.999150          18         71  neutral
# 66            are in with  0.503296          14         40  neutral
# 67           was doing so  0.487799          29         79  neutral
# 68       one did anything  0.189698          15         39  neutral
# 71         would like him -0.950520          25         48  neutral
# 72         the wrong body  1.838012          13         53  neutral

# %%
print("Bigram Increase")
print(df_increase.sort_values("t_score", ascending=False).head(50))

print("Bigram Decrease")
print(df_decrease.sort_values("t_score").head(50))

print("Bigram Neutral")
print(df_neutral.sort_values("t_score", ascending=False).head(50))
# Out:
# Bigram Increase
#                            trigram    t_score  freq_short  freq_long  category
# 51335       delivered the opposite  38.640693           1       1504  increase
# 192706         delivered peace and  38.601855           1       1501  increase
# 256484         place everything is  38.601855           1       1501  increase
# 59364         the place everything  38.588901           1       1500  increase
# 102084                 now 30 more  38.588901           1       1500  increase
# 124998              took office 15  38.550011           1       1497  increase
# 223330        when bidenharis took  38.537039           1       1496  increase
# 170555      bidenharis took office  38.537039           1       1496  increase
# 219159         was when bidenharis  38.537039           1       1496  increase
# 233525         and prosperity when  38.526623           2       1506  increase
# 204486          immigrants some of  38.524063           1       1495  increase
# 144308           office 15 million  38.524063           1       1495  increase
# 40308           prosperity when he  38.487674           2       1503  increase
# 261412           expensive than it  38.444347           4       1521  increase
# 85389   bidenharris have delivered  38.400410           3       1507  increase
# 110744     office bidenharris have  38.361339           3       1504  increase
# 279287     illegal immigrants some  38.361339           3       1504  increase
# 260800            opposite we have  38.274981           4       1508  increase
# 287457               have wars all  38.235790           4       1505  increase
# 191829           30 more expensive  38.228823           5       1515  increase
# 67769           have delivered the  38.215752           5       1514  increase
# 253619                   is now 30  38.058545           5       1502  increase
# 215658           everything is now  37.631248          10       1521  increase
# 171218                we have wars  37.122176          20       1580  increase
# 20674              the opposite we  36.853087          18       1541  increase
# 188490       in office bidenharris  36.839634          18       1540  increase
# 140928               wars all over  35.798664          41       1667  increase
# 39992          more expensive than  34.806106          44       1619  increase
# 169381          15 million illegal  34.490908          66       1767  increase
# 57307   million illegal immigrants  33.236688         223       2648  increase
# 150831            for including me  29.493842          44       1260  increase
# 61279           which are hardened  29.464162           1        879  increase
# 173157                 it was when  28.601311         157       1916  increase
# 111648               some of which  27.223233          47       1144  increase
# 197201          is supporting evil  27.076770           1        744  increase
# 56263           is over supporting  26.928656           1        736  increase
# 172645   americas destruction this  26.928656           1        736  increase
# 87938         evil lying installed  26.798385           1        729  increase
# 140302           save america wake  26.758415           3        748  increase
# 203898                up people or  26.471202           4        743  increase
# 150087     demonrats is supporting  26.419690           0        698  increase
# 122939   lying installed demonrats  26.362853           0        695  increase
# 64462       installed demonrats is  26.362853           0        695  increase
# 234904         over supporting the  26.244017           4        731  increase
# 32319               the evil lying  26.222434           5        740  increase
# 86502            people or america  26.184735           6        748  increase
# 253245         supporting the evil  25.708799           7        733  increase
# 52748                 boom we must  25.517901           1        662  increase
# 219831                 than it was  25.391205         290       2335  increase
# 173102                for the seat  24.832194         143       1578  increase
# Bigram Decrease
#                                trigram    t_score  freq_short  freq_long  \
# 11164                       at the rnc -59.629001        8741       6907
# 52182             the democratic party -57.708832       32674      51478
# 22042             the republican party -48.850174       23607      37274
# 99860                      is going to -42.444389       15686      23913
# 19616              thank you president -37.899656        2221        920
# 263596                     this is the -36.958761       12416      19160
# 186093                    this is what -34.980707        7463      10116
# 256254                   im voting for -32.818557        4036       4353
# 287078                      out of the -32.300908       13850      23451
# 212779                 the white house -30.005889       13840      24148
# 23563                       the gop is -29.518877        6750       9935
# 52176                        i love it -28.970689        1363        623
# 58824                       a maga hat -28.302616        1992       1591
# 22740                      of the race -28.084614        3830       4722
# 228422                     all the way -28.050343        3556       4238
# 284913                     to drop out -27.411942        5296       7559
# 144247                     in the race -27.280141        3798       4788
# 146085                    this is maga -27.115450        1123        453
# 93106                    be voting for -26.394373        3001       3492
# 203710                     needs to be -26.302342        7168      11454
# 84730                     cant wait to -26.232491        1906       1671
# 211545                   found this on -26.167579         727         44
# 78149                this on newsbreak -26.026182         713         37
# 70397                       at the dnc -25.847827        3145       3822
# 149311                     i cant wait -25.838911        1905       1710
# 19804              the worst president -25.653885        2541       2788
# 75877                    the maga cult -25.558709        3445       4405
# 58504               the rnc convention -25.438899        2093       2058
# 116335                    i found this -25.145186         770        150
# 212101          the conservative party -25.132428        4860       7138
# 81076                      going to be -24.991902        9592      16733
# 172596                    looks like a -24.968100        1609       1329
# 46526              america great again -24.908517        4244       5996
# 281391                 is maga country -24.575202         778        193
# 224693              make america great -24.233033        4061       5759
# 18886              republican party is -24.062305        3965       5604
# 274745                   cant wait for -23.957034        1605       1418
# 34499                      i wonder if -23.364792        1937       2022
# 3659    the bidenharris administration -23.085519        6528      10859
# 188347             democratic party is -22.670984        4663       7192
# 29926                and the democrats -22.645293        3207       4388
# 160908                doesnt even know -22.416949        1271       1031
# 122643                     this guy is -22.099642        1510       1439
# 152350                       yes or no -22.006419         895        507
# 242792                       you are a -21.948728        7332      12768
# 61661                     drops out of -21.681335         777        367
# 71591                      this is how -21.626536        2713       3607
# 229995                      of the rnc -21.550302        1643       1712
# 158910                     maga is the -21.414927        1584       1626
# 148678                       is a maga -21.407439        1204       1010
#
#         category
# 11164   decrease
# 52182   decrease
# 22042   decrease
# 99860   decrease
# 19616   decrease
# 263596  decrease
# 186093  decrease
# 256254  decrease
# 287078  decrease
# 212779  decrease
# 23563   decrease
# 52176   decrease
# 58824   decrease
# 22740   decrease
# 228422  decrease
# 284913  decrease
# 144247  decrease
# 146085  decrease
# 93106   decrease
# 203710  decrease
# 84730   decrease
# 211545  decrease
# 78149   decrease
# 70397   decrease
# 149311  decrease
# 19804   decrease
# 75877   decrease
# 58504   decrease
# 116335  decrease
# 212101  decrease
# 81076   decrease
# 172596  decrease
# 46526   decrease
# 281391  decrease
# 224693  decrease
# 18886   decrease
# 274745  decrease
# 34499   decrease
# 3659    decrease
# 188347  decrease
# 29926   decrease
# 160908  decrease
# 122643  decrease
# 152350  decrease
# 242792  decrease
# 61661   decrease
# 71591   decrease
# 229995  decrease
# 158910  decrease
# 148678  decrease
# Bigram Neutral
#                            trigram   t_score  freq_short  freq_long category
# 82895              about their own  1.999668         136        404  neutral
# 203625               on all issues  1.999150          18         71  neutral
# 221388         the legal authority  1.999150          18         71  neutral
# 112271                its a direct  1.999150          18         71  neutral
# 83971               both sides lie  1.999150          18         71  neutral
# 176565            the structure of  1.999150          18         71  neutral
# 284942                he also told  1.999150          18         71  neutral
# 119611            flew on epsteins  1.999150          18         71  neutral
# 228719           support those who  1.999150          18         71  neutral
# 72605              evil people who  1.999150          18         71  neutral
# 192408              was obvious he  1.999150          18         71  neutral
# 17054            released a report  1.999150          18         71  neutral
# 119234                   over it i  1.999150          18         71  neutral
# 237798            like laken riley  1.999150          18         71  neutral
# 264791      never voted republican  1.999150          18         71  neutral
# 23703            they believed the  1.999150          18         71  neutral
# 42317              the media tried  1.999150          18         71  neutral
# 161035              and well being  1.999150          18         71  neutral
# 73038                 right i know  1.999150          18         71  neutral
# 232207  thirdparty risk management  1.999150          18         71  neutral
# 52401         to the international  1.999150          18         71  neutral
# 35393                     1 im not  1.999150          18         71  neutral
# 129411              win instead of  1.999150          18         71  neutral
# 54274              trying to score  1.999150          18         71  neutral
# 99593                 47 is trumps  1.999150          18         71  neutral
# 274783           america to become  1.999150          18         71  neutral
# 209887            candidate to the  1.999150          18         71  neutral
# 71903                 on the bible  1.999150          18         71  neutral
# 133346                of the title  1.999150          18         71  neutral
# 98872             and other social  1.999150          18         71  neutral
# 206138          inside the capitol  1.999150          18         71  neutral
# 234094             paul pelosi was  1.999150          18         71  neutral
# 149116                who didnt do  1.999150          18         71  neutral
# 4607        inflation inflation is  1.999150          18         71  neutral
# 220147            his own policies  1.999150          18         71  neutral
# 197834                we have high  1.999150          18         71  neutral
# 11765                   of his pen  1.999150          18         71  neutral
# 121231        bringing in millions  1.999150          18         71  neutral
# 123321                  was a deal  1.999150          18         71  neutral
# 208234                  to and you  1.999150          18         71  neutral
# 16022               how it affects  1.999150          18         71  neutral
# 93005               got less votes  1.999150          18         71  neutral
# 242824    getting your information  1.999150          18         71  neutral
# 95756           raise their prices  1.999150          18         71  neutral
# 280576    through executive orders  1.999150          18         71  neutral
# 36311                in to replace  1.999150          18         71  neutral
# 124237               anyway i dont  1.999150          18         71  neutral
# 65                    the issue he  1.999150          18         71  neutral
# 221938                sent the fbi  1.999150          18         71  neutral
# 93164                 to break our  1.999150          18         71  neutral
